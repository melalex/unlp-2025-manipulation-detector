# %%
import google.generativeai as genai
import pandas as pd
import random
import uuid
import json
import numpy as np
from collections import defaultdict

import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent))
from src.definitions import RAW_DATA_FOLDER, PROJECT_ROOT_DIR, EXTERNAL_DATA_FOLDER

# %%
df = pd.read_parquet(RAW_DATA_FOLDER / "techniques-classification.parquet")

# Завантажити описи технік
with open(PROJECT_ROOT_DIR / "src/data/technique_descriptions.json", encoding='utf-8') as f:
    TECHNIQUE_DESCRIPTIONS = json.load(f)

# %%
genai.configure(api_key="AIzaSyBAgWYwuCYOkfiM2txUtWBvbHQAio8jqAI")
model = genai.GenerativeModel("gemini-1.5-flash")


def generate_with_multiple_techniques(lang: str, techniques: list, examples: list):
    techniques_desc = "\n".join([f"- {tech}: {TECHNIQUE_DESCRIPTIONS[tech]}" for tech in techniques])
    examples_text = "\n".join([f"Приклад {i+1}:\n{ex}" for i, ex in enumerate(examples)])

    prompt = f"""
    Створи новий маніпулятивний текст {lang} мовою, який використовує техніки: {', '.join(techniques)}.
    Текст повинен бути природнім і містити тригерні слова.

    Техніки:
    {techniques_desc}

    Приклади:
    {examples_text}

    Формат відповіді: {{
        "content": "текст...",
        "techniques": {json.dumps(techniques)},
        "trigger_words": ["список", "слів"]
    }}
    """

    try:
        response = model.generate_content(prompt)
        cleaned = response.text.replace("```json", "").replace("```", "").strip()
        return json.loads(cleaned)
    except Exception as e:
        print(f"Помилка: {str(e)}")
        return None

df['techniques'] = df['techniques'].apply(lambda x: x.tolist() if isinstance(x, np.ndarray) else x)
df['techniques'] = df['techniques'].apply(lambda x: x if x else [])

# Аналіз розподілу кількості технік у вихідному датасеті
technique_count_dist = defaultdict(int)
for _, row in df.iterrows():
    if row['techniques']:
        technique_count_dist[len(row['techniques'])] += 1

# Перетворюємо у відсотковий розподіл
total = sum(technique_count_dist.values())
technique_count_pct = {k: v/total for k, v in technique_count_dist.items()}

# Функція для вибору кількості технік згідно з розподілом
def sample_technique_count(pct_dict):
    counts = list(pct_dict.keys())
    weights = [pct_dict[count] for count in counts]
    return random.choices(counts, weights=weights, k=1)[0]

# Створюємо пул технік на основі частоти використання
technique_freq = defaultdict(int)
for _, row in df.iterrows():
    for tech in row['techniques']:
        technique_freq[tech] += 1

# Функція для вибору N технік на основі їх частоти
def sample_techniques(technique_freq, n, lang=None):
    techniques = list(technique_freq.keys())
    weights = [technique_freq[tech] for tech in techniques]
    
    if lang:
        # Якщо потрібно, можна додати фільтрацію за мовою
        lang_techniques = []
        lang_weights = []
        for tech, weight in zip(techniques, weights):
            tech_rows = df[df['techniques'].apply(lambda x: tech in x)]
            if lang in tech_rows['lang'].unique():
                lang_techniques.append(tech)
                lang_weights.append(weight)
        
        if lang_techniques:
            return random.choices(lang_techniques, weights=lang_weights, k=n)
    
    return random.choices(techniques, weights=weights, k=n)

# Генерація нових даних з різною кількістю технік
new_data = []
languages = df['lang'].unique()

# Кількість нових записів, які потрібно згенерувати
num_generations = 10000

for i in range(num_generations):
    if i % 100 == 0:
        print(f"Згенеровано {i} прикладів")
    # Вибір мови
    lang = random.choice(languages)
    
    # Визначення кількості технік для цього прикладу
    num_techniques = sample_technique_count(technique_count_pct)
    
    # Вибір технік
    selected_techniques = sample_techniques(technique_freq, num_techniques, lang)
    # Видалення дублікатів, якщо вони є
    selected_techniques = list(set(selected_techniques))
    
    # Якщо після видалення дублікатів список порожній, продовжуємо
    if not selected_techniques:
        continue
    
    # Пошук існуючих прикладів
    filtered = df[
        (df['lang'] == lang) &
        (df['techniques'].apply(lambda x: all(t in x for t in selected_techniques)))
    ]
    
    # Адаптивна вибірка
    sample_size = min(3, len(filtered))
    if sample_size == 0:
        # Якщо немає точних прикладів, спробуємо знайти приклади з хоча б однією з обраних технік
        filtered = df[
            (df['lang'] == lang) &
            (df['techniques'].apply(lambda x: any(t in x for t in selected_techniques)))
        ]
        sample_size = min(3, len(filtered))
        
    if sample_size == 0:
        print(f"⚠️ Немає прикладів для {selected_techniques} ({lang})")
        continue
    
    examples = filtered.sample(sample_size, replace=(sample_size > len(filtered)))['content'].tolist()
    
    # Генерація нового прикладу
    result = generate_with_multiple_techniques(lang, selected_techniques, examples)
    if result:
        new_data.append({
            'id': str(uuid.uuid4()),
            'content': result['content'],
            'lang': lang,
            'manipulative': True,
            'techniques': np.array(result['techniques']),
            'trigger_words': np.array(result.get('trigger_words', []))
        })
        # print(f"✅ Згенеровано приклад з {len(selected_techniques)} техніками: {selected_techniques}")

# %%time
# Out:
# Згенеровано 0 прикладів
# Згенеровано 100 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 428 (char 429)
# Згенеровано 200 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 43 (char 44)
# Помилка: Expecting ',' delimiter: line 2 column 50 (char 51)
# Помилка: Expecting ',' delimiter: line 2 column 41 (char 42)
# Помилка: Expecting ',' delimiter: line 2 column 34 (char 35)
# Помилка: Expecting ',' delimiter: line 2 column 47 (char 48)
# Помилка: Expecting ',' delimiter: line 2 column 151 (char 152)
# Згенеровано 300 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 209 (char 210)
# Помилка: Expecting ',' delimiter: line 2 column 395 (char 396)
# Помилка: Expecting ',' delimiter: line 2 column 35 (char 36)
# Згенеровано 400 прикладів
# Згенеровано 500 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 280 (char 281)
# Згенеровано 600 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 138 (char 139)
# Помилка: Expecting ',' delimiter: line 2 column 48 (char 49)
# Помилка: Expecting ',' delimiter: line 2 column 98 (char 99)
# Помилка: Expecting ',' delimiter: line 2 column 50 (char 51)
# Помилка: Expecting ',' delimiter: line 2 column 706 (char 707)
# Згенеровано 700 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 115 (char 116)
# Згенеровано 800 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 29 (char 30)
# Помилка: Expecting ',' delimiter: line 2 column 69 (char 70)
# Помилка: Expecting ',' delimiter: line 2 column 25 (char 26)
# Згенеровано 900 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 124 (char 125)
# Помилка: Expecting ',' delimiter: line 2 column 38 (char 39)
# Помилка: Expecting ',' delimiter: line 2 column 104 (char 105)
# Помилка: Expecting ',' delimiter: line 2 column 40 (char 41)
# Згенеровано 1000 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 169 (char 170)
# Згенеровано 1100 прикладів
# Згенеровано 1200 прикладів
# Помилка: Expecting ',' delimiter: line 2 column
прикладів
# Помилка: Expecting ',' delimiter: line 2 column 29 (char 30)
# Помилка: Expecting ',' delimiter: line 2 column 243 (char 244)
# Помилка: Expecting ',' delimiter: line 2 column 220 (char 221)
# Помилка: Expecting ',' delimiter: line 2 column 59 (char 60)
# Згенеровано 3800 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 58 (char 59)
# Згенеровано 3900 прикладів
# Згенеровано 4000 прикладів
# Згенеровано 4100 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 37 (char 38)
# Помилка: Expecting ',' delimiter: line 2 column 122 (char 123)
# Згенеровано 4200 прикладів
# Помилка: Invalid control character at: line 2 column 725 (char 726)
# Помилка: Expecting ',' delimiter: line 2 column 61 (char 62)
# Помилка: Expecting ',' delimiter: line 2 column 19 (char 20)
# Помилка: Expecting ',' delimiter: line 2 column 35 (char 36)
# Помилка: Expecting ',' delimiter: line 2 column 252 (char 253)
# Згенеровано 4300 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 26 (char 27)
# Помилка: Expecting ',' delimiter: line 2 column 51 (char 52)
# Згенеровано 4400 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 1036 (char 1037)
# Згенеровано 4500 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 35 (char 36)
# Помилка: Expecting ',' delimiter: line 2 column 37 (char 38)
# Згенеровано 4600 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 29 (char 30)
# Згенеровано 4700 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 30 (char 31)
# Помилка: Expecting ',' delimiter: line 2 column 45 (char 46)
# Помилка: Expecting ',' delimiter: line 2 column 42 (char 43)
# Помилка: Expecting ',' delimiter: line 2 column 62 (char 63)
# Помилка: Expecting ',' delimiter: line 2 column 277 (char 278)
# Згенеровано 4800 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 206 (char 207)
# Помилка: Expecting ',' delimiter: line 2 column 229 (char 230)
# Помилка: Expecting ',' delimiter: line 2 column 535 (char 536)
# Помилка: Expecting ',' delimiter: line 2 column 184 (char 185)
# Згенеровано 4900 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 59 (char 60)
# Згенеровано 5000 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 500 (char 501)
# Помилка: Expecting ',' delimiter: line 2 column 65 (char 66)
# Помилка: Expecting ',' delimiter: line 2 column 182 (char 183)
# Помилка: Expecting ',' delimiter: line 2 column 49 (char 50)
# Помилка: Invalid operation: The `response.parts` quick accessor requires a single candidate, but but `response.candidates` is empty.
# This appears to be caused by a blocked prompt, see `response.prompt_feedback`: block_reason: PROHIBITED_CONTENT
#
# Згенеровано 5100 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 490 (char 491)
# Згенеровано 5200 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 35 (char 36)
# Помилка: Expecting ',' delimiter: line 2 column 51 (char 52)
# Помилка: Expecting ',' delimiter: line 2 column 57 (char 58)
# Згенеровано 5300 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 242 (char 243)
# Помилка: Expecting ',' delimiter: line 2 column 79 (char 80)
# Згенеровано 5400 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 36 (char 37)
# Згенеровано 5500 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 88 (char 89)
# Помилка: Expecting ',' delimiter: line 2 column 68 (char 69)
# Згенеровано 5600 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 59 (char 60)
# Помилка: Expecting ',' delimiter: line 2 column 57 (char 58)
# Помилка: Expecting ',' delimiter: line 2 column 39 (char 40)
# Згенеровано 5700 прикладів
# Згенеровано 5800 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 402 (char 403)
# Помилка: Expecting ',' delimiter: line 2 column 491 (char 492)
# Згенеровано 5900 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 28 (char 29)
# Помилка: Expecting ',' delimiter: line 2 column 38 (char 39)
# Помилка: Expecting ',' delimiter: line 2 column 336 (char 337)
# Згенеровано 6000 прикладів
# Помилка: Expecting ',' delimiter: line 2 column 191 (char 192)
# Помилка: Expecting ',' delimiter: line 2 column 52 (char 53)
# Помилка: Expecting ',' delimiter: line 2 column 1126 (char 1127)
# Помилка: Extra data: line 7 column 1 (char 699)
# Згенеровано 6100 прикладів
# Помилка: Expecting ',' delimiter: line 2 column
in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      75 try:
# ---> 76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
#
# File c:\Users\b.yarinko\Desktop\Code\unlp-2025-manipulation-detector\.venv\lib\site-packages\grpc\_interceptor.py:277, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     268 def __call__(
#     269     self,
#     270     request: Any,
#    (...)
#     275     compression: Optional[grpc.Compression] = None,
#     276 ) -> Any:
# --> 277     response, ignored_call = self._with_call(
#     278         request,
#     279         timeout=timeout,
#     280         metadata=metadata,
#     281         credentials=credentials,
#     282         wait_for_ready=wait_for_ready,
#     283         compression=compression,
#     284     )
#     285     return response
#
# File c:\Users\b.yarinko\Desktop\Code\unlp-2025-manipulation-detector\.venv\lib\site-packages\grpc\_interceptor.py:332, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     329 call = self._interceptor.intercept_unary_unary(
#     330     continuation, client_call_details, request
#     331 )
# --> 332 return call.result(), call
#
# File c:\Users\b.yarinko\Desktop\Code\unlp-2025-manipulation-detector\.venv\lib\site-packages\grpc\_channel.py:440, in _InactiveRpcError.result(self, timeout)
#     439 """See grpc.Future.result."""
# --> 440 raise self
#
# File c:\Users\b.yarinko\Desktop\Code\unlp-2025-manipulation-detector\.venv\lib\site-packages\grpc\_interceptor.py:315, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     314 try:
# --> 315     response, call = self._thunk(new_method).with_call(
#     316         request,
#     317         timeout=new_timeout,
#     318         metadata=new_metadata,
#     319         credentials=new_credentials,
#     320         wait_for_ready=new_wait_for_ready,
#     321         compression=new_compression,
#     322     )
#     323     return _UnaryOutcome(response, call)
#
# File c:\Users\b.yarinko\Desktop\Code\unlp-2025-manipulation-detector\.venv\lib\site-packages\grpc\_channel.py:1198, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1192 (
#    1193     state,
#    1194     call,
#    1195 ) = self._blocking(
#    1196     request, timeout, metadata, credentials, wait_for_ready, compression
#    1197 )
# -> 1198 return _end_unary_response_blocking(state, call, True, None)
#
# File c:\Users\b.yarinko\Desktop\Code\unlp-2025-manipulation-detector\.venv\lib\site-packages\grpc\_channel.py:1006, in _end_unary_response_blocking(state, call, with_call, deadline)
#    1005 else:
# -> 1006     raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "failed to connect to all addresses; last error: UNKNOWN: ipv4:172.217.19.106:443: tcp handshaker shutdown"
# 	debug_error_string = "UNKNOWN:Error received from peer  {created_time:"2025-03-17T06:51:22.9617473+00:00", grpc_status:14, grpc_message:"failed to connect to all addresses; last error: UNKNOWN: ipv4:172.217.19.106:443: tcp handshaker shutdown"}"
# >
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# File c:\Users\b.yarinko\Desktop\Code\unlp-2025-manipulation-detector\.venv\lib\site-packages\google\api_core\retry\retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     143 try:
# --> 144     result = target()
#     145     if inspect.isawaitable(result):
#
# File c:\Users\b.yarinko\Desktop\Code\unlp-2025-manipulation-detector\.venv\lib\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File c:\Users\b.yarinko\Desktop\Code\unlp-2025-manipulation-detector\.venv\lib\site-packages\google\api_core\grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# ServiceUnavailable: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:172.217.19.106:443: tcp handshaker shutdown
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 128
#     125 examples = filtered.sample(sample_size, replace=(sample_size > len(filtered)))['content'].tolist()
#     127 # Генерація нового прикладу
# --> 128 result = generate_with_multiple_techniques(lang, selected_techniques, examples)
#     129 if result:
#     130     new_data.append({
#     131         'id': str(uuid.uuid4()),
#     132         'content': result['content'],
#    (...)
#     136         'trigger_words': np.array(result.get('trigger_words', []))
#     137     })
#
# Cell In[7], line 28, in generate_with_multiple_techniques(lang, techniques, examples)
#      10 prompt = f"""
#      11 Створи новий маніпулятивний текст {lang} мовою, який використовує техніки: {', '.join(techniques)}.
#      12 Текст повинен бути природнім і містити тригерні слова.
#    (...)
#      24 }}
#      25 """
#      27 try:
# ---> 28     response = model.generate_content(prompt)
#      29     cleaned = response.text.replace("```json", "").replace("```", "").strip()
#      30     return json.loads(cleaned)
#
# File c:\Users\b.yarinko\Desktop\Code\unlp-2025-manipulation-detector\.venv\lib\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
#     335         return generation_types.GenerateContentResponse.from_response(response)
#     336 except google.api_core.exceptions.InvalidArgument as e:
#
# File c:\Users\b.yarinko\Desktop\Code\unlp-2025-manipulation-detector\.venv\lib\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     832 self._validate_universe_domain()
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#     843 return response
#
# File c:\Users\b.yarinko\Desktop\Code\unlp-2025-manipulation-detector\.venv\lib\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File c:\Users\b.yarinko\Desktop\Code\unlp-2025-manipulation-detector\.venv\lib\site-packages\google\api_core\retry\retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File c:\Users\b.yarinko\Desktop\Code\unlp-2025-manipulation-detector\.venv\lib\site-packages\google\api_core\retry\retry_unary.py:164, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     153         _retry_error_helper(
#     154             exc,
#     155             deadline,
#    (...)
#     161             timeout,
#     162         )
#     163         # if exception not raised, sleep before next attempt
# --> 164         time.sleep(sleep)
#     166 raise ValueError("Sleep generator stopped yielding sleep values.")
#
# KeyboardInterrupt:

# %%
EXTERNAL_DATA_FOLDER.mkdir(parents=True, exist_ok=True)

new_data = pd.DataFrame(new_data)

new_data.to_csv(EXTERNAL_DATA_FOLDER / "10000gemini-generated-data-v2.csv", index=False)

# %% [markdown]
# # Генерація даних з однаковою кількістю для кожного класу

# %%
genai.configure(api_key="AIzaSyBAgWYwuCYOkfiM2txUtWBvbHQAio8jqAI")
model = genai.GenerativeModel("gemini-1.5-flash")

def generate_with_multiple_techniques(lang: str, techniques: list, examples: list):
    techniques_desc = "\n".join([f"- {tech}: {TECHNIQUE_DESCRIPTIONS[tech]}" for tech in techniques])
    examples_text = "\n".join([f"Приклад {i+1}:\n{ex}" for i, ex in enumerate(examples)])

    prompt = f"""
    Створи новий маніпулятивний текст {lang} мовою, який використовує техніки: {', '.join(techniques)}.
    Текст повинен бути природнім і містити тригерні слова.

    Техніки:
    {techniques_desc}

    Приклади:
    {examples_text}

    Формат відповіді: {{
        "content": "текст...",
        "techniques": {json.dumps(techniques)},
        "trigger_words": ["список", "слів"]
    }}
    """

    try:
        response = model.generate_content(prompt)
        cleaned = response.text.replace("```json", "").replace("```", "").strip()
        return json.loads(cleaned)
    except Exception as e:
        print(f"Помилка: {str(e)}")
        return None

# Перетворення списку технік
df['techniques'] = df['techniques'].apply(lambda x: x.tolist() if isinstance(x, np.ndarray) else x)
df['techniques'] = df['techniques'].apply(lambda x: x if x else [])

# Отримання всіх унікальних технік з датасету
all_techniques = set()
for _, row in df.iterrows():
    all_techniques.update(row['techniques'])
all_techniques = list(all_techniques)

print(f"Знайдено {len(all_techniques)} унікальних технік")

# Функція для вибору прикладів з певною технікою
def get_examples_for_technique(technique, lang, num_examples=3):
    filtered = df[
        (df['lang'] == lang) &
        (df['techniques'].apply(lambda x: technique in x))
    ]
    
    sample_size = min(num_examples, len(filtered))
    if sample_size == 0:
        # Якщо немає прикладів з цією технікою в цій мові, спробуємо знайти в іншій мові
        filtered = df[df['techniques'].apply(lambda x: technique in x)]
        sample_size = min(num_examples, len(filtered))
        
    if sample_size == 0:
        return []
    
    return filtered.sample(sample_size, replace=(sample_size > len(filtered)))['content'].tolist()

# Генерація нових даних з рівномірним розподілом технік
new_data = []
languages = df['lang'].unique()

# Кількість записів для кожної техніки
examples_per_technique = 1000  # Наприклад, 100 прикладів для кожної техніки
total_examples = examples_per_technique * len(all_techniques)

# Лічильник для кожної техніки
technique_counters = {tech: 0 for tech in all_techniques}

# Генерація
while sum(technique_counters.values()) < total_examples:
    # Вибираємо техніку з найменшою кількістю прикладів
    technique = min(technique_counters.items(), key=lambda x: x[1])[0]
    
    # Вибір мови
    lang = random.choice(languages)
    
    # Додаємо ще 1-2 техніки випадково, щоб зробити приклади більш різноманітними
    # але зберігаємо основну техніку
    num_additional = random.choice([0, 1, 2])
    all_other_techniques = [t for t in all_techniques if t != technique]
    additional_techniques = random.sample(all_other_techniques, min(num_additional, len(all_other_techniques)))
    
    selected_techniques = [technique] + additional_techniques
    
    # Пошук існуючих прикладів
    examples = get_examples_for_technique(technique, lang)
    
    if not examples:
        print(f"⚠️ Немає прикладів для техніки {technique} ({lang})")
        continue
    
    # Генерація нового прикладу
    result = generate_with_multiple_techniques(lang, selected_techniques, examples)
    if result:
        new_data.append({
            'id': str(uuid.uuid4()),
            'content': result['content'],
            'lang': lang,
            'manipulative': True,
            'techniques': np.array(selected_techniques),
            'trigger_words': np.array(result.get('trigger_words', []))
        })
        
        # Збільшуємо лічильник для основної техніки
        technique_counters[technique] += 1
        
        if sum(technique_counters.values()) % 100 == 0:
            print(f"Згенеровано {sum(technique_counters.values())} прикладів")
            # Показуємо поточний розподіл
            print(f"Поточний розподіл: {technique_counters}")

# Перевірка рівномірності розподілу
print("\nФінальний розподіл технік:")
for tech, count in technique_counters.items():
    print(f"{tech}: {count} прикладів")

# Збереження у вихідний файл
new_df = pd.DataFrame(new_data)
new_df.to_csv("balanced_manipulative_dataset.csv", index=False)
print(f"Збережено {len(new_data)} прикладів з рівномірним розподілом технік")
# Out:
# Знайдено 10 унікальних технік
# Помилка: Expecting ',' delimiter: line 2 column 122 (char 123)
# Помилка: Expecting ',' delimiter: line 2 column 113 (char 114)
# Згенеровано 100 прикладів
# Поточний розподіл: {'appeal_to_fear': 10, 'glittering_generalities': 10, 'bandwagon': 10, 'fud': 10, 'cherry_picking': 10, 'loaded_language': 10, 'euphoria': 10, 'straw_man': 10, 'cliche': 10, 'whataboutism': 10}
# Помилка: Expecting ',' delimiter: line 2 column 1081 (char 1082)
# Помилка: Expecting ',' delimiter: line 2 column 53 (char 54)
# Помилка: Expecting ',' delimiter: line 2 column 59 (char 60)
# Помилка: Expecting ',' delimiter: line 2 column 436 (char 437)
# Помилка: Expecting ',' delimiter: line 2 column 32 (char 33)
# Згенеровано 200 прикладів
# Поточний розподіл: {'appeal_to_fear': 20, 'glittering_generalities': 20, 'bandwagon': 20, 'fud': 20, 'cherry_picking': 20, 'loaded_language': 20, 'euphoria': 20, 'straw_man': 20, 'cliche': 20, 'whataboutism': 20}
# Згенеровано 300 прикладів
# Поточний розподіл: {'appeal_to_fear': 30, 'glittering_generalities': 30, 'bandwagon': 30, 'fud': 30, 'cherry_picking': 30, 'loaded_language': 30, 'euphoria': 30, 'straw_man': 30, 'cliche': 30, 'whataboutism': 30}
# Помилка: Expecting ',' delimiter: line 2 column 38 (char 39)
# Помилка: Expecting ',' delimiter: line 2 column 422 (char 423)
# Помилка: Expecting ',' delimiter: line 2 column 78 (char 79)
# Згенеровано 400 прикладів
# Поточний розподіл: {'appeal_to_fear': 40, 'glittering_generalities': 40, 'bandwagon': 40, 'fud': 40, 'cherry_picking': 40, 'loaded_language': 40, 'euphoria': 40, 'straw_man': 40, 'cliche': 40, 'whataboutism': 40}
# Помилка: Expecting ',' delimiter: line 2 column 520 (char 521)
# Помилка: Expecting ',' delimiter: line 2 column 354 (char 355)
# Помилка: Expecting ',' delimiter: line 2 column 37 (char 38)
# Помилка: Expecting ',' delimiter: line 2 column 38 (char 39)
# Помилка: Expecting ',' delimiter: line 2 column
# Помилка: Expecting ',' delimiter: line 2 column 92 (char 93)
# Помилка: Expecting ',' delimiter: line 2 column 60 (char 61)
# Помилка: Expecting ',' delimiter: line 2 column 475 (char 476)
# Помилка: Invalid control character at: line 2 column 80 (char 81)
# Помилка: Expecting ',' delimiter: line 2 column 26 (char 27)
# Помилка: Expecting ',' delimiter: line 2 column 26 (char 27)
# Помилка: Expecting ',' delimiter: line 2 column 47 (char 48)
# Помилка: Expecting ',' delimiter: line 2 column 80 (char 81)
# Згенеровано 9800 прикладів
# Поточний розподіл: {'appeal_to_fear': 980, 'glittering_generalities': 980, 'bandwagon': 980, 'fud': 980, 'cherry_picking': 980, 'loaded_language': 980, 'euphoria': 980, 'straw_man': 980, 'cliche': 980, 'whataboutism': 980}
# Помилка: Expecting ',' delimiter: line 2 column 438 (char 439)
# Згенеровано 9900 прикладів
# Поточний розподіл: {'appeal_to_fear': 990, 'glittering_generalities': 990, 'bandwagon': 990, 'fud': 990, 'cherry_picking': 990, 'loaded_language': 990, 'euphoria': 990, 'straw_man': 990, 'cliche': 990, 'whataboutism': 990}
# Помилка: Expecting ',' delimiter: line 2 column 189 (char 190)
# Помилка: Expecting ',' delimiter: line 2 column 795 (char 796)
# Помилка: Expecting ',' delimiter: line 2 column 35 (char 36)
# Помилка: Expecting ',' delimiter: line 2 column 47 (char 48)
# Згенеровано 10000 прикладів
# Поточний розподіл: {'appeal_to_fear': 1000, 'glittering_generalities': 1000, 'bandwagon': 1000, 'fud': 1000, 'cherry_picking': 1000, 'loaded_language': 1000, 'euphoria': 1000, 'straw_man': 1000, 'cliche': 1000, 'whataboutism': 1000}
#
# Фінальний розподіл технік:
# appeal_to_fear: 1000 прикладів
# glittering_generalities: 1000 прикладів
# bandwagon: 1000 прикладів
# fud: 1000 прикладів
# cherry_picking: 1000 прикладів
# loaded_language: 1000 прикладів
# euphoria: 1000 прикладів
# straw_man: 1000 прикладів
# cliche: 1000 прикладів
# whataboutism: 1000 прикладів
# Збережено 10000 прикладів з рівномірним розподілом технік

# %% [markdown]
# # Генерація неманіпулятивних технік

# %%
# Конфігурація моделі
genai.configure(api_key="AIzaSyBAgWYwuCYOkfiM2txUtWBvbHQAio8jqAI")
model = genai.GenerativeModel("gemini-1.5-flash")

def generate_similar_non_manipulative_text(lang: str, examples: list):
    """
    Генерує новий текст на основі 4 випадкових прикладів
    """
    examples_text = "\n".join([f"📌 Приклад {i+1}:\n{ex}" for i, ex in enumerate(examples)])
    
    prompt = f"""
    Створи оригінальний текст {lang} мовою, який імітує стиль та структуру наведених прикладів.
    Текст має бути натуральним і не містити маніпулятивних елементів.
    
    Приклади для наслідування:
    {examples_text}
    
    Формат відповіді (обов'язково JSON):
    {{
        "content": "твій текст..."
    }}
    """

    try:
        response = model.generate_content(prompt)
        text = response.text
        
        # Спроба знайти JSON у відповіді
        try:
            json_str = text[text.find('{'):text.rfind('}')+1]
            return json.loads(json_str)
        except:
            print(f"Помилка парсингу JSON: {text}")
            return None
            
    except Exception as e:
        print(f"Помилка генерації: {str(e)}")
        return None

# Фільтрація датасету
non_manipulative_df = df[df['manipulative'] == False]

if non_manipulative_df.empty:
    print("❗ Використовую весь датасет для генерації")
    non_manipulative_df = df

new_data = []
TEXTS_PER_LANG = 1000

for lang in non_manipulative_df['lang'].unique():
    lang_examples = non_manipulative_df[non_manipulative_df['lang'] == lang]
    
    if lang_examples.empty:
        print(f"⏩ Пропускаємо {lang} - немає прикладів")
        continue
        
    total_examples = len(lang_examples)
    print(f"\n🌍 Мова: {lang} | Прикладів: {total_examples}")
    
    for i in range(TEXTS_PER_LANG):
        # Вибір 4 унікальних прикладів з можливістю повтору
        samples = lang_examples.sample(
            n=4, 
            replace=total_examples < 4
        )['content'].tolist()
        
        result = generate_similar_non_manipulative_text(lang, samples)
        
        if result and 'content' in result:
            new_data.append({
                'id': uuid.uuid4().hex,
                'content': result['content'],
                'lang': lang,
                'manipulative': False,
                'techniques': None,
                'trigger_words': None
            })
            
        print(f"✅ Згенеровано {i+1}/{TEXTS_PER_LANG}", end='\r')

# Збереження результатів
pd.DataFrame(new_data).to_csv("nonmanipulative_generated_texts.csv", index=False)
print(f"\n🎉 Успішно згенеровано {len(new_data)} текстів!")
# Out:
# 🌍 Мова: uk | Прикладів: 812
# Помилка парсингу JSON: ```json
# {
#   "content": "📢  Сьогодні вранці на Львівщині зафіксовано незвичне явище: зграя диких качок, що складалась приблизно з 500 особин, вибудувала унікальний геометричний візерунок на замерзлому озері.  Орнітологи з Національного університету "Львівська політехніка" виїхали на місце для дослідження цього феномену.\n\nДетальніше:\nbirds.lviv.ua/geometricducks (посилання - гіпотетичне)"
# }
# ```
#
# Помилка парсингу JSON: ```json
# {
#   "content": "🍂\n\nУ Карпатах розпочався сезон "золотий осінь".\n\nПо всій території Карпатського регіону спостерігається яскраве забарвлення листя. Температура повітря вдень сягає +10...+15°С, вночі +5...+10°С. Очікується сонячна погода з невеликою хмарністю. Туристичні маршрути відкриті, але рекомендується взяти з собою теплий одяг та зручне взуття.\n\nДля більш детальної інформації звертайтеся до місцевих туристичних інформаційних центрів.\n\n👉\n\nКарпатські новини\nСтікери\n|\nНадіслати новину"
# }
# ```
#
# Помилка парсингу JSON: ```json
# {
#   "content": "Київська міська рада
# затвердила
#  нову програму підтримки малого та середнього бізнесу на 2024 рік.
# Заплановано виділення 150 мільйонів гривень на гранти та пільгові кредити для підприємців.
# Програма передбачає  підтримку  бізнесу у сферах туризму,  IT,  харчової промисловості та  виробництва. \n\nОкремо  зазначимо, що
# Мер Києва
# оголосив
# про  запуск  спеціальної  онлайн-платформи для подачі заявок на отримання фінансової допомоги.  \n\nДетальніше про програму та умови участі можна дізнатися на сайті Київської міської ради."
# }
# ```
#
# ✅ Згенеровано 1000/1000
# 🌍 Мова: ru | Прикладів: 421
# Помилка парсингу JSON: ```json
# {
#   "content": "Требуются сварщики в г. Новосибирск. Опыт работы обязателен, зарплата от 80000 рублей.  Работа вахтовым методом, 60/30. Предоставляется проживание и питание.  Обращаться по телефону: +7952-123-45-67. \n\nВласти США обеспокоены ростом напряженности на границе между Индией и Пакистаном. Сообщается, что  США призывают обе стороны к деэскалации и мирному разрешению конфликта.  По данным источников,  увеличение военного присутствия в регионе повышает риск непреднамеренного столкновения и эскалации конфликта.  Госсекретарь США заявил о готовности оказать дипломатическую поддержку для мирных переговоров. \n\nВ 1985 году в городе Чернобыль произошла крупная авария на химическом заводе.  Слухи о выбросе токсичных веществ распространились молниеносно, вызвав панику среди населения. Власти эвакуировали жителей близлежащих населенных пунктов.  Были задействованы все доступные силы для ликвидации последствий аварии.  По официальным данным, жертв среди населения не было, однако,  последствия аварии ощущались еще несколько лет.  \n\nСтатья в журнале "The Lancet" описывает опыт работы психологов с ветеранами войны в Афганистане.  Многочисленные интервью с военными  показывают высокий уровень посттравматического стрессового расстройства (ПТСР).  Отмечается нехватка квалифицированных специалистов и ресурсов для оказания необходимой психологической помощи.  Один из ветеранов описывает свои ощущения после возвращения домой как ощущение постоянной угрозы и неспособность вернуться к нормальной жизни.  Лечение включает в себя как медикаментозную терапию, так и психотерапию, но  долгосрочные результаты пока неизвестны."
# }
# ```
#
# Помилка парсингу JSON: ```json
# {
#   "content": "Новая система ПВО "Кентавр":  первые испытания\n\nУкраинские инженеры представили прототип мобильной системы противовоздушной обороны под кодовым названием \"Кентавр\".  Система, разработанная на базе шасси  многоцелевого бронетранспортера,  обладает высокой маневренностью и способностью к быстрому развертыванию.  В ходе испытаний \"Кентавр\" успешно поразил несколько воздушных целей, включая беспилотные летательные аппараты различных типов и имитаторы крылатых ракет.\n\nГлавным преимуществом \"Кентавра\" является его  модульность.  Система может быть легко адаптирована под различные типы ракет и  имеет расширенные возможности по интеграции с системами разведки и управления огнем.  Это позволяет эффективно противодействовать современным угрозам с воздуха.\n\nДальнейшие испытания \"Кентавра\" запланированы на ближайшие месяцы.  Разработчики планируют усовершенствовать систему,  увеличив дальность и точность поражения целей,  а также улучшив  защищенность от электронного подавления.\n\nБудем следить за развитием проекта.  Подробности — позже.\n\nПодписаться на обновления | Поделиться новостью"
# }
# ```
#
# Помилка парсингу JSON: ```json
# {
#   "content": "В городе Николаеве началась реконструкция стадиона "Спартак".  Работы проводятся в рамках городской программы развития спортивной инфраструктуры.  Подрядчиком выступила компания "СтройГарант", выигравшая тендер с предложением в 25 миллионов гривен.  В проекте заявлено использование импортного газона последнего поколения, стоимость которого составляет 10 миллионов гривен.  Однако,  по данным независимых экспертов, аналогичный газон можно приобрести у отечественных производителей за 6 миллионов гривен.  Разница в цене объясняется в тендерной документации использованием более сложной технологии укладки,  достоверность чего пока не подтверждена.  Также, вызывает вопросы стоимость дренажной системы – 5 миллионов гривен, в то время как аналогичные системы, согласно рыночным ценам, стоят на 2 миллиона дешевле.  Пресс-служба "СтройГарант" пока не предоставила комментариев по поводу разницы в стоимости материалов.  Заказчиком проекта выступает городской департамент спорта и туризма, который обещает провести внутреннюю проверку обоснованности расценок, указанных в проекте, по окончании работ.  Проектную документацию разработало  архитектурное бюро "НиколаевПроект".  Представители бюро отказались от комментариев, сославшись на загруженность."
# }
# ```
#
# }
# ```
#
# Помилка парсингу JSON: ```json
# {
#   "content": "Первый запуск экспериментального реактора ТОР-100 состоялся 15 марта 1965 года.  На фотографиях — момент достижения критической мощности.  \n\nСегодня стало известно о плановых ремонтных работах на реакторе, которые начнутся в ближайшие дни и продлятся около месяца.\n\nМинистр энергетики России, Алексей Миллер, поздравил коллектив исследовательского института с успешным завершением этапа испытаний.\n«Проект ТОР-100 является прорывом в области ядерной энергетики.  Его реализация позволит значительно повысить энергоэффективность и снизить зависимость от традиционных источников.  Перед нами стоят амбициозные задачи по развитию атомной энергетики, и успешная работа над ТОР-100 — важный шаг на этом пути.  Мы планируем в дальнейшем масштабировать технологию и внедрять её на других объектах.  Впереди  – новые проекты, новые возможности и новые достижения». \n\nПредставитель оппозиционной партии заявил, что  информация о плановых работах на реакторе недостаточно прозрачна, и потребовал  более подробного отчета о расходах и соблюдении норм безопасности.\n\nИсточник в Госдуме подтвердил, что  ряд депутатов намерены  иницировать парламентское расследование по  вопросам финансирования проекта ТОР-100.  Также, по его словам,  не исключается создание специальной комиссии для изучения вопросов  безопасности работы  экспериментального реактора. "Подобные проекты требуют максимально  прозрачного  и  тщательного контроля", -  подчеркнул источник."
# }
# ```
#
# Помилка парсингу JSON: ```json
# {
#   "content": "Вчера вечером в районе станции метро "Спортивная" произошла небольшая авария. \nПо словам очевидцев, столкнулись два легковых автомобиля. \nКак сообщили в ГИБДД, пострадавших нет. \nДвижение транспорта было временно затруднено, но сейчас уже восстановлено. \nНа месте аварии работали сотрудники ДПС. \nПодробности выясняются.\nФотографии с места происшествия можно посмотреть в нашем телеграм-канале. \nПодписаться| \nРеклама| \nСвязаться с нами"
# }
# ```
#
# Помилка парсингу JSON: ```json
# {
#   "content": "В сети появилось видео с места крушения вертолета Ми-8 в Брянской области. \n\nНа кадрах, которые, предположительно, были сняты очевидцем, видны обломки вертолета, разбросанные на значительной территории. \n\nПо предварительной информации, предоставленной местными телеграм-каналами, на борту находились три человека, все погибли. \n\nОфициального подтверждения информации от российских властей пока нет.  Однако, источники в экстренных службах сообщают о сложности доступа к месту крушения из-за труднопроходимой местности.\n\nТакже отмечается, что на месте работают следственные органы, которые выясняют обстоятельства произошедшего. Предварительная версия – техническая неисправность, но рассматриваются и другие возможные причины. \n\nПо словам представителя местного союза ветеранов боевых действий,  в ближайшее время планируется сбор средств на помощь семьям погибших. "Это трагедия для всей области, мы не можем оставить их в беде", - заявил он."
# }
# ```
#
# Помилка парсингу JSON: ```json
# {
#   "content": "🔥 Ураган "Ярослав" обрушился на Одессу! 🌪️\n\nСильный ветер, ливень и град повредили десятки домов и автомобилей.  Мэр города Геннадий Труханов обратился к жителям с просьбой оставаться дома и соблюдать осторожность.  \n\n📸 Фото и видео последствий урагана уже заполонили соцсети.  Ущерб оценивается в миллионы гривен. \n\n🆘  Информация о пострадавших уточняется.  Следите за обновлениями.\n\n➡️ Подробности на нашем сайте: [ссылка на несуществующий сайт]\n\n#Одесса #Ураган #СтихийноеБедствие #Погода #Новости"
# }
# ```
#
# Помилка парсингу JSON: ```json
# {
#   "content": "⚡️Экстренное сообщение из Берлина:
#
# Канцлер Шольц подтвердил планы по поставке Украине новых танков Leopard 2, но с некоторыми оговорками.  Речь идёт о 14 танках из запасов бундесвера, передача которых начнётся в ближайшие недели.  Шольц подчеркнул важность координации действий с союзниками по НАТО и необходимость избегать эскалации конфликта.
#
# Подробности:
#
# * Поставки будут осуществляться в рамках согласованного с союзниками плана.
# * Германия продолжит оказывать Украине всестороннюю поддержку, включая обучение украинских экипажей.
# * Шольц призвал Россию к немедленному прекращению боевых действий и возвращению к мирным переговорам.
#
# С полным текстом заявления канцлера можно ознакомиться по ссылке: [ссылка на источник].
#
# #Германия #Украина #Leopard2 #НАТО #Шольц  |  #ПоддержатьУкраину |  #НовостиЕвропы"
# }
# ```
#
# Помилка парсингу JSON: ```json
# {
#   "content": "⚡️  ВСУ уничтожили российский комплекс ПВО "Панцирь-С1" под Бахмутом.\n\n— Данные разведки.\n\nПо предварительной информации, удар был нанесен высокоточным оружием.  Комплекс был полностью выведен из строя,  погибли несколько российских военнослужащих.  Информация о потерях уточняется.  В настоящее время проводятся дополнительные мероприятия по подтверждению данных и оценке масштабов ущерба.\n\nПодписаться / Прислать новость"
# }
# ```
#
# ✅ Згенеровано 1000/1000
# 🎉 Успішно згенеровано 1986 текстів!

# %%
t = pd.DataFrame(new_data)
t
# Out:
#                                     id  \
# 0     beddc0f7d9ee4760832468aff2467a09
# 1     4701e4e55752424dab2d79d5119b98ad
# 2     e505bf9cdf0a485b853b09c5087de2a3
# 3     03c57eac457c4ee4b59c5aaa433e7d91
# 4     3b69c5936abe463e8693fb5ce311b302
# ...                                ...
# 1981  5ffc46ed5cc04ea49541c7db692509b7
# 1982  d4ffecd7a36443749d1f27e892a9d774
# 1983  36f2e24298cf4c3692cb7ac12968e90d
# 1984  8f1d7c6084ff4a0eb38c0df0ee603a4f
# 1985  b875de5649dc427baa787fac75d32a62
#
#                                                 content lang  manipulative  \
# 0     🏘️\nУ Львові відкрили перший в Україні музей в...   uk         False
# 1     ❗ Повідомлення з Харкова:  Сильна хуртовина ус...   uk         False
# 2     Засідання уряду: обговорення нових програм під...   uk         False
# 3     Центр досліджень української мови та культури ...   uk         False
# 4     📌 Приклад:  Оновлення системи електронного док...   uk         False
# ...                                                 ...  ...           ...
# 1981  Итоги рабочей поездки в село Верхние Дубровцы:...   ru         False
# 1982  ⚡️\nРосстат опубликовал данные о средней зарпл...   ru         False
# 1983  Власти Новосибирской области планируют вложить...   ru         False
# 1984  Слушайте, сегодня утром читал, что в  Бразилии...   ru         False
# 1985  • Минобороны России заявило об уничтожении укр...   ru         False
#
#      techniques trigger_words
# 0          None          None
# 1          None          None
# 2          None          None
# 3          None          None
# 4          None          None
# ...         ...           ...
# 1981       None          None
# 1982       None          None
# 1983       None          None
# 1984       None          None
# 1985       None          None
#
# [1986 rows x 6 columns]
